# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Notebook Assignment

# %% [markdown]
# ### Introduction

# %% [markdown]
# #### Data science languages are:
# - Python
# - R
# - SQL

# %% [markdown]
# ### Data science library are:¶
# - Matplotlib
# - Pandas
# - Numpy

# %% [markdown]
# ### Data Science Tools
#
# | Category              | Tools/Technologies                          | Purpose/Use Case                                |
# |-----------------------|---------------------------------------------|------------------------------------------------|
# | Programming Languages | Python, R, SQL                              | Data analysis, modeling, querying              |
# | Data Manipulation     | Pandas, dplyr, NumPy                        | Cleaning, wrangling, and transforming data     |
# | Visualization         | Matplotlib, Seaborn, ggplot2, Plotly        | Creating charts, plots, and dashboards         |

# %% [markdown]
# ### Arithmetic Expression Examples
#
# Arithmetic expressions are used to perform basic mathematical operations.
# Here are some common examples:
#
# - **Addition**: \( 5 + 3 = 8 \)
# - **Subtraction**: \( 10 - 4 = 6 \)
# - **Multiplication**: \( 7 \times 6 = 42 \)
# - **Division**: \( 20 \div 5 = 4 \)
# - **Exponentiation**: \( 2^3 = 8 \)
# - **Modulus (Remainder)**: \( 17 \bmod 3 = 2 \)

# %%
 (2 + 4) * 3
# Out:
# 18

# %%
minutes = 150  
hours = minutes / 60

print(f"{minutes} minutes is equal to {hours} hours")
# Out:
# 150 minutes is equal to 2.5 hours

# %% [markdown]
# ### Objectives
#
# The main objectives of this notebook are:
#
# - Understand the basics of data science tools and workflows
# - Practice writing and formatting Markdown cells
# - Explore arithmetic expressions and their Python equivalents
# - Build clarity in presenting results with professional formatting

# %% [markdown]
# ### ✍️ Author
#
# **Name:** PRANAB
